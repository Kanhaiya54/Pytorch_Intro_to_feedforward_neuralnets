# %%
import torch

# %%
x=torch.rand(2,2)

# %%
y=torch.rand(2,2)

# %%
y.add_(x)
# Out:
# tensor([[0.3864, 0.8989],
#         [1.2398, 1.4145]])

# %%
z=torch.add(x,y)

# %%
print(z)
# Out:
# tensor([[0.3876, 1.5074],
#         [2.1806, 2.3380]])

# %%
z=torch.div(x,y)

# %%
print(z)
# Out:
# tensor([[0.0031, 0.6769],
#         [0.7588, 0.6529]])

# %%
o_s=torch.zeros(2,2)

# %%
print(o_s)
# Out:
# tensor([[0., 0.],
#         [0., 0.]])

# %%
i_s=torch.ones(2,2)
print(i_s)
# Out:
# tensor([[1., 1.],
#         [1., 1.]])

# %%
z
# Out:
# tensor([[0.0031, 0.6769],
#         [0.7588, 0.6529]])

# %%
print(z[0,0].item())
# Out:
# 0.003122942289337516

# %%
x=torch.rand(4,4)
y=x.view(8,-1)

# %%
print(y)
# Out:
# tensor([[0.0206, 0.9159],
#         [0.1302, 0.6882],
#         [0.6567, 0.6556],
#         [0.7714, 0.0899],
#         [0.8483, 0.7967],
#         [0.4141, 0.9702],
#         [0.7227, 0.1645],
#         [0.8722, 0.9274]])

# %%
rand_num=torch.rand(10,10)

# %%
rand_num.view(2,-1)
# Out:
# tensor([[0.2982, 0.6671, 0.1128, 0.7141, 0.5765, 0.6507, 0.6797, 0.9280, 0.0829,
#          0.9539, 0.6391, 0.7535, 0.7562, 0.6852, 0.0871, 0.0593, 0.8304, 0.3513,
#          0.4107, 0.5999, 0.2422, 0.0715, 0.5944, 0.8322, 0.0624, 0.6976, 0.3284,
#          0.3291, 0.3017, 0.2328, 0.4683, 0.9113, 0.4608, 0.7982, 0.7746, 0.4770,
#          0.6167, 0.0037, 0.7437, 0.0374, 0.0399, 0.6560, 0.3156, 0.4250, 0.9452,
#          0.6378, 0.3581, 0.0081, 0.6169, 0.3425],
#         [0.4089, 0.0680, 0.4104, 0.6924, 0.8666, 0.2161, 0.7316, 0.0878, 0.2705,
#          0.0927, 0.1284, 0.5490, 0.7816, 0.1967, 0.7537, 0.9840, 0.5158, 0.7515,
#          0.1258, 0.8928, 0.3890, 0.6906, 0.2428, 0.4695, 0.7138, 0.5943, 0.3030,
#          0.3776, 0.4813, 0.4990, 0.2715, 0.3625, 0.8733, 0.7860, 0.7263, 0.2487,
#          0.4339, 0.3331, 0.5791, 0.5384, 0.5169, 0.2785, 0.5994, 0.0189, 0.8778,
#          0.9201, 0.5626, 0.2960, 0.4589, 0.8880]])

# %%
import numpy as np

# %%
a=torch.ones(5)

# %%
print(a)
# Out:
# tensor([1., 1., 1., 1., 1.])

# %%
b=a.numpy

# %%
print(type(b))
# Out:
# <class 'builtin_function_or_method'>

# %%
torch.cuda.get_device_name(0)
# Out:
# 'GeForce GTX 1060'

# %%
a=torch.ones(5,5)

# %%
b=a.numpy()

# %%
type(b)
# Out:
# numpy.ndarray

# %%
a=np.ones(5)

# %%
a
# Out:
# array([1., 1., 1., 1., 1.])

# %%
b=torch.from_numpy(a)

# %%
print(b)
# Out:
# tensor([1., 1., 1., 1., 1.], dtype=torch.float64)

# %%
b+=1

# %%
a
# Out:
# array([2., 2., 2., 2., 2.])

# %%
a=a+1

# %%
print(torch.device("cuda"))
# Out:
# cuda

# %%
x=torch.ones(5, requires_grad=True)

# %%
x
# Out:
# tensor([1., 1., 1., 1., 1.], requires_grad=True)

# %%
a=np.ones(2)

# %%
a
# Out:
# array([1., 1.])

# %%
b=torch.from_numpy(a)

# %%
b
# Out:
# tensor([1., 1.], dtype=torch.float64)

# %%
a+=1

# %%
b
# Out:
# tensor([1., 1.], dtype=torch.float64)

# %%
print(a)
# Out:
# [3. 3.]

# %%
print(b)
# Out:
# tensor([1., 1.], dtype=torch.float64)

# %%
if torch.cuda.is_available():
    device=torch.device("cuda")
    x=torch.ones(5,device=device)
    y=torch.ones(5)
    y=y.to(device)
    z= x+y
    z=z.to("cpu")

# %%
torch.cuda.is_available()
# Out:
# True

# %%
a=torch.tensor(2)

# %%
b=a.numpy()

# %%
a
# Out:
# tensor(2)

# %%
b
# Out:
# array(2, dtype=int64)

# %%
a=a+1

# %%
b
# Out:
# array(2, dtype=int64)

# %%
a
# Out:
# tensor(3)

# %% [markdown]
# # NUMPY RUNS ON CPU, AND TENSORS RUNS ON GPU. IF YOU INCREASE NUMPY ARRAYS, IT WILL NOT HAVE EFFECT ON GPU VALUES(TENSORS)
# # IF THEY DONT HAVE GPU ON THE SYSTEM, THEN THE TENSORS AND NUMPY RUN ON CPU.

# %%
x=torch.ones(3,requires_grad=True)

# %%
x
# Out:
# tensor([1., 1., 1.], requires_grad=True)

# %%
y=x*x+1

# %%
y
# Out:
# tensor([2., 2., 2.], grad_fn=<AddBackward0>)

# %%
#y=y.mean()

# %%
y
# Out:
# tensor([2., 2., 2.], grad_fn=<AddBackward0>)

# %%
x=torch.ones(3,requires_grad=True)

# %%
x
# Out:
# tensor([1., 1., 1.], requires_grad=True)

# %%
y=2*x*x+3

# %%
y
# Out:
# tensor([5., 5., 5.], grad_fn=<AddBackward0>)

# %%
v=torch.tensor([0.1,0.01,0.001])

# %%
y.backward(v)

# %%
x.grad
# Out:
# tensor([0.4000, 0.0400, 0.0040])

# %%
(torch.ones(3)*3).sum()
# Out:
# tensor(9.)

# %% [markdown]
# # Backpropagation

# %%
import torch 
x=torch.tensor(1.0)
y=torch.tensor(2.0)

w=torch.tensor(1.0,requires_grad=True)

y_hat=w*x
loss=(y_hat-y)**2

print(loss)
# Out:
# tensor(1., grad_fn=<PowBackward0>)

# %%
loss.backward(w) #dloss/dw
print(w.grad) #gradients.
# Out:
# tensor(-2.)

# %% [markdown]
# # Linear Regression using Numpy

# %%
import numpy as np

#f=w*x  Ex: f=2*x (weights=2)
X=np.array([1,2,3,4],dtype=np.float32)
Y=np.array([2,4,6,8],dtype=np.float32)

w=1.2

#model prediction
def forward(x):
    return w*x

#loss = MSE
def loss(y,y_predicted):
    return ((y_predicted-y)**2).mean()

#gradient
#MSE(Loss) = 1/N * (w*x - y)**2
#Loss(J) derivates dJ/dw= 1/N * d/dw((wx-y)^2).d/dw(wx-y)
 #dJ/dw=2*x(w*x-Y)

def gradient(x,y,y_predicted):
    return np.dot(2*x,y_predicted-y).mean()

print(f'Prediction before training: f(5)={forward(5):.3f}')
print("Initial Weights",w)

#Training
learning_rate=0.01
n_iter=10

for epoch in range(n_iter):
    #prediction=forward_pass
    y_pred=forward(X)
    
    #loss
    l=loss(Y,y_pred)
    
    #gradients
    dw= gradient(X,Y,y_pred)
    
    
    #updating_weights
    w-=learning_rate*dw

    if epoch%1==0:
        print(f'epoch {epoch+1}: w={w:.3f},loss={l:.8f}')

print("Weights after training",w)
print(f'Prediction after the training: f(5)={forward(5):.3f}')
# Out:
# Prediction before training: f(5)=6.000
# Initial Weights 1.2
# epoch 1: w=1.680,loss=4.79999924
# epoch 2: w=1.872,loss=0.76800019
# epoch 3: w=1.949,loss=0.12288000
# epoch 4: w=1.980,loss=0.01966083
# epoch 5: w=1.992,loss=0.00314570
# epoch 6: w=1.997,loss=0.00050332
# epoch 7: w=1.999,loss=0.00008053
# epoch 8: w=1.999,loss=0.00001288
# epoch 9: w=2.000,loss=0.00000206
# epoch 10: w=2.000,loss=0.00000033
# Weights after training 1.9999160981178281
# Prediction after the training: f(5)=10.000

# %% [markdown]
# # Linear Regression with Pytorch

# %%
import torch


#f=w*x  Ex: f=2*x (weights=2)
X=torch.tensor([1,2,3,4],dtype=torch.float32)
Y=torch.tensor([2,4,6,8],dtype=torch.float32)

w=torch.tensor(0.0,dtype=torch.float32,requires_grad=True)

#model prediction
def forward(x):
    return w*x

#loss = MSE
def loss(y,y_predicted):
    return ((y_predicted-y)**2).mean()

#gradient
#MSE(Loss) = 1/N * (w*x - y)**2
#Loss(J) derivates dJ/dw= 1/N * d/dw((wx-y)^2).d/dw(wx-y)
 
#dJ/dw=2*x(w*x-Y)


print(f'Prediction before training: f(5)={forward(5):.3f}')
print("Initial Weights",w)

#Training
learning_rate=0.01
n_iter=100

for epoch in range(n_iter):
    #prediction=forward_pass
    y_pred=forward(X)
    
    #loss
    l=loss(Y,y_pred)  # OUTPUT FUNCTION
    
    l.backward()  # l.backward calculates the gradient with respect to the input function.

    with torch.no_grad():     #torch.no_grad is from AutoGrad Package, and we dont want any grad, is because, it stacks up the gradient values in the .grad package and even in the computational package.
        w-=learning_rate*w.grad
    
    w.grad.zero_()
        
    if epoch%10==0:
        print(f'epoch {epoch+1}: w={w:.3f},loss={l:.8f}')

print("Weights after training",w)
print(f'Prediction after the training: f(5)={forward(5):.3f}')
# Out:
# Prediction before training: f(5)=0.000
# Initial Weights tensor(0., requires_grad=True)
# epoch 1: w=0.300,loss=30.00000000
# epoch 11: w=1.665,loss=1.16278565
# epoch 21: w=1.934,loss=0.04506890
# epoch 31: w=1.987,loss=0.00174685
# epoch 41: w=1.997,loss=0.00006770
# epoch 51: w=1.999,loss=0.00000262
# epoch 61: w=2.000,loss=0.00000010
# epoch 71: w=2.000,loss=0.00000000
# epoch 81: w=2.000,loss=0.00000000
# epoch 91: w=2.000,loss=0.00000000
# Weights after training tensor(2.0000, requires_grad=True)
# Prediction after the training: f(5)=10.000

# %% [markdown]
# # Using Neural Network

# %%
import torch
import torch.nn as nn

#f=w*x  Ex: f=2*x (weights=2)
X=torch.tensor([1,2,3,4],dtype=torch.float32)
Y=torch.tensor([2,4,6,8],dtype=torch.float32)

w=torch.tensor(0,dtype=torch.float32,requires_grad=True)

#model prediction
def forward(x):
    return w*x


#gradient
#MSE(Loss) = 1/N * (w*x - y)**2
#Loss(J) derivates dJ/dw= 1/N * d/dw((wx-y)^2).d/dw(wx-y)
 
#dJ/dw=2*x(w*x-Y)


print(f'Prediction before training: f(5)={forward(5):.3f}')
print("Initial Weights",w)

#Training
learning_rate=0.01
n_iter=100

loss=nn.MSELoss()
optimizer=torch.optim.SGD([w],lr=learning_rate) #optimizing weights using learning_rate.


for epoch in range(n_iter):
    #prediction=forward_pass
    y_pred=forward(X)
    
    #loss
    l=loss(Y,y_pred)  # OUTPUT FUNCTION
    
    l.backward()  # l.backward calculates the gradient with respect to the input function.
    
    optimizer.step()#Update weights
    
    optimizer.zero_grad()
    
    if epoch%10==0:
        print(f'epoch {epoch+1}: w={w:.3f},loss={l:.8f}')

print("Weights after training",w)
print(f'Prediction after the training: f(5)={forward(5):.3f}')
# Out:
# Prediction before training: f(5)=0.000
# Initial Weights tensor(0., requires_grad=True)
# epoch 1: w=0.300,loss=30.00000000
# epoch 11: w=1.665,loss=1.16278565
# epoch 21: w=1.934,loss=0.04506890
# epoch 31: w=1.987,loss=0.00174685
# epoch 41: w=1.997,loss=0.00006770
# epoch 51: w=1.999,loss=0.00000262
# epoch 61: w=2.000,loss=0.00000010
# epoch 71: w=2.000,loss=0.00000000
# epoch 81: w=2.000,loss=0.00000000
# epoch 91: w=2.000,loss=0.00000000
# Weights after training tensor(2.0000, requires_grad=True)
# Prediction after the training: f(5)=10.000

# %%
X=torch.tensor([[1],[2],[3],[4],[5]])
X.shape
# Out:
# torch.Size([5, 1])

# %%
x = torch.tensor([[1.0, -1.0],
                  [0.0,  1.0],
                  [0.0,  0.0]])

x.shape  # = 2
# Out:
# torch.Size([3, 2])

# %% [markdown]
# # Linear Regression with Model Pytorch

# %%
import torch
import torch.nn as nn

#f=w*x  Ex: f=2*x (weights=2)

X=torch.tensor([[1],[2],[3],[4]],dtype=torch.float32)
Y=torch.tensor([[2],[4],[6],[8]],dtype=torch.float32)

n_sample,n_features=X.shape

print(n_sample,n_features)

X_test=torch.tensor([5],dtype=torch.float32)

input_size=n_features
output_size=n_features

model=nn.Linear(input_size,output_size)

print(f'Prediction before training: f(5)={model(X_test).item():.3f}')

[w,b]=model.parameters()

print("Model Parameters w before training\n w: ",w[0][0].item())
print(" Bias b: ",b[0].item())

print("\n")
#Training
learning_rate=0.1
n_iter=200

loss=nn.MSELoss()
optimizer=torch.optim.SGD(model.parameters(),lr=learning_rate) #optimizing weights using learning_rate.


for epoch in range(n_iter):
    #prediction=forward_pass
    y_pred=model(X)
    
    #loss
    l=loss(Y,y_pred)  # OUTPUT FUNCTION
    
    l.backward()  # l.backward calculates the gradient with respect to the input function. (dl/dw)
    
    optimizer.step()#Update weights
    
    optimizer.zero_grad() #makes grad 0.
    
    if epoch%10==0:
        [w,b]=model.parameters()
        print(f'epoch {epoch+1}: w={w[0][0].item():.3f},b={b[0].item():.3f},loss={l:.8f}')

print("Weights after training",w)
print(f'Prediction after the training: f(5)={model(X_test).item():.3f}')
# Out:
# 4 1
# Prediction before training: f(5)=-1.812
# Model Parameters w before training
#  w:  -0.39344167709350586
#  Bias b:  0.15497195720672607
#
#
# epoch 1: w=3.119,b=1.321,loss=41.13365555
# epoch 11: w=1.814,b=0.630,loss=0.08225101
# epoch 21: w=1.844,b=0.459,loss=0.03735591
# epoch 31: w=1.885,b=0.339,loss=0.02033702
# epoch 41: w=1.915,b=0.250,loss=0.01107306
# epoch 51: w=1.937,b=0.184,loss=0.00602904
# epoch 61: w=1.954,b=0.136,loss=0.00328269
# epoch 71: w=1.966,b=0.100,loss=0.00178735
# epoch 81: w=1.975,b=0.074,loss=0.00097317
# epoch 91: w=1.981,b=0.055,loss=0.00052987
# epoch 101: w=1.986,b=0.040,loss=0.00028850
# epoch 111: w=1.990,b=0.030,loss=0.00015708
# epoch 121: w=1.993,b=0.022,loss=0.00008553
# epoch 131: w=1.994,b=0.016,loss=0.00004657
# epoch 141: w=1.996,b=0.012,loss=0.00002536
# epoch 151: w=1.997,b=0.009,loss=0.00001381
# epoch 161: w=1.998,b=0.007,loss=0.00000752
# epoch 171: w=1.998,b=0.005,loss=0.00000409
# epoch 181: w=1.999,b=0.004,loss=0.00000223
# ...

# %%
import torch 
import torch.nn as nn
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt

#0)prepare data
X_numpy,y_numpy=datasets.make_regression(n_samples=100,n_features=1,noise=20,random_state=1)

#print(y_numpy)

X=torch.from_numpy(X_numpy.astype(np.float32))
y=torch.from_numpy(y_numpy.astype(np.float32))

#print('X',X)
#print('y',y)

#print('X.shape',X.shape)
#print('y.shape',y.shape)

y=y.view(y.shape[0],1)

#print('y',y)
#print('y',y.shape)
#1)model
#2)loss and optimizer

#1)Model

n_samples,n_features=X.shape
input_size=n_features
output_size=1

model=nn.Linear(input_size,output_size)

#2) loss and optimizer
learning_rate=0.01
criterion=nn.MSELoss()
optimizer=torch.optim.SGD(model.parameters(),lr=learning_rate)

num_epochs=100
for epoch in range(num_epochs):
    y_pred=model(X)
    loss=criterion(y_pred,y)
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()

    if (epoch+1)%10==0:
        [w,b]=model.parameters()
        print(f'epoch {epoch}: w={w[0][0].item():.3f},b={b[0].item():.3f},loss={l.item():.8f}')

        
        
predicted=model(X).detach().numpy()
plt.plot(X_numpy,y_numpy,'ro')
plt.plot(X_numpy,predicted,'b')
# Out:
# epoch 9: w=12.924,b=1.049,loss=0.00000070
# epoch 19: w=23.158,b=2.316,loss=0.00000070
# epoch 29: w=31.878,b=3.245,loss=0.00000070
# epoch 39: w=39.309,b=3.914,loss=0.00000070
# epoch 49: w=45.643,b=4.384,loss=0.00000070
# epoch 59: w=51.044,b=4.704,loss=0.00000070
# epoch 69: w=55.649,b=4.909,loss=0.00000070
# epoch 79: w=59.576,b=5.029,loss=0.00000070
# epoch 89: w=62.926,b=5.087,loss=0.00000070
# epoch 99: w=65.784,b=5.099,loss=0.00000070

# %% [markdown]
# # Logistic Regression using Pytorch

# %%
import torch 
import torch.nn as nn
import numpy as np
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split


#0)prepare dataset

bc=datasets.load_breast_cancer()



X,y=bc.data,bc.target

n_samples,n_features=X.shape

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1234)

#scale (0 mean, unit variance with Logistic Regression)
sc=StandardScaler()

X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)


X_train=torch.from_numpy(X_train.astype(np.float32))
X_test=torch.from_numpy(X_test.astype(np.float32))
y_train=torch.from_numpy(y_train.astype(np.float32))
y_test=torch.from_numpy(y_test.astype(np.float32))

y_train=y_train.view(y_train.shape[0],1)
y_test=y_test.view(y_test.shape[0],1) 

#1)model has 2 parts
#1. f=wx+b, 
#2.we apply sigmoid at the end for Logistic Regression


class LogisticRegression(nn.Module):
    def __init__(self,n_input_features):
        super(LogisticRegression,self).__init__()
        self.linear=nn.Linear(n_input_features,1)
        
    
    def forward(self,x):
        y_predicted=torch.sigmoid(self.linear(x))
        return y_predicted

model = LogisticRegression(n_features)
#2)loss and optimizer
learning_rate=0.01
criterion=nn.BCELoss()
optimizer=torch.optim.SGD(model.parameters(),lr=learning_rate)

#3)training loop 
num_epochs=100
for epoch in range(num_epochs):
    #forward pass and loss
    y_predicted=model.forward(X_train)
    loss=criterion(y_predicted,y_train)

    #backward pass
    loss.backward() #dl/dw
    
    #updates
    optimizer.step() #w=w-dl/dw
    
    optimizer.zero_grad()
    
    if(epoch+1)%10==0:
        print(f"epoch:{epoch+1}, loss={loss.item():.4f} ")

#4)
with torch.no_grad():
    y_predicted=model.forward(X_test)
    y_predicted_cls=y_predicted.round()
    acc=y_predicted_cls.eq(y_test).sum() / float(y_test.shape[0])
    print(acc*100)
# Out:
# epoch:10, loss=0.5575
# epoch:20, loss=0.4601
# epoch:30, loss=0.3975
# epoch:40, loss=0.3537
# epoch:50, loss=0.3214
# epoch:60, loss=0.2963
# epoch:70, loss=0.2763
# epoch:80, loss=0.2598
# epoch:90, loss=0.2460
# epoch:100, loss=0.2343
# tensor(93.8596)

# %% [markdown]
# # Dataset and Dataset Loader

# %%
import torch 
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np
import math 

class WineDataset(Dataset):
    def __init__(self):
        xy=np.loadtxt('wine.csv',delimiter=',',dtype=np.float32,skiprows=1)
        self.x=torch.from_numpy(xy[:,1:])
        self.y=torch.from_numpy(xy[:,[0]])
        self.n_samples=xy.shape[0]
        
        
    def __getitem__(self,index):
            return self.x[index],self.y[index]

    def __len__(self):
        return self.n_samples

    
dataset=WineDataset()
dataloader=DataLoader(dataset=dataset,batch_size=4,shuffle=True,num_workers=0)

#raining loop
num_epochs=2
total_samples=len(dataset)
n_iterations=math.ceil(total_samples/4)  #Each batch is of size 4 and we are sending 45 batches of each size 4, 45 times == 45 iterations
print(total_samples,n_iterations)

for epoch in range(num_epochs):
    for i,(input,labels) in enumerate(dataloader):
        if (i+1)%5==0:
            print(f' epoch {epoch+1}/{num_epochs}, step {i+1}/{n_iterations},  inputs {input.shape}')
# Out:
# 178 45
#  epoch 1/2, step 5/45,  inputs torch.Size([4, 13])
#  epoch 1/2, step 10/45,  inputs torch.Size([4, 13])
#  epoch 1/2, step 15/45,  inputs torch.Size([4, 13])
#  epoch 1/2, step 20/45,  inputs torch.Size([4, 13])
#  epoch 1/2, step 25/45,  inputs torch.Size([4, 13])
#  epoch 1/2, step 30/45,  inputs torch.Size([4, 13])
#  epoch 1/2, step 35/45,  inputs torch.Size([4, 13])
#  epoch 1/2, step 40/45,  inputs torch.Size([4, 13])
#  epoch 1/2, step 45/45,  inputs torch.Size([2, 13])
#  epoch 2/2, step 5/45,  inputs torch.Size([4, 13])
#  epoch 2/2, step 10/45,  inputs torch.Size([4, 13])
#  epoch 2/2, step 15/45,  inputs torch.Size([4, 13])
#  epoch 2/2, step 20/45,  inputs torch.Size([4, 13])
#  epoch 2/2, step 25/45,  inputs torch.Size([4, 13])
#  epoch 2/2, step 30/45,  inputs torch.Size([4, 13])
#  epoch 2/2, step 35/45,  inputs torch.Size([4, 13])
#  epoch 2/2, step 40/45,  inputs torch.Size([4, 13])
#  epoch 2/2, step 45/45,  inputs torch.Size([2, 13])

# %% [markdown]
# # Dataset Transforms

# %%
import torch 
import torchvision
 
    
dataset=torchvision.datasets.MNIST(
    root='./data',download=True,transform=torchvision.transforms.ToTensor())

# %% [markdown]
# ## In init, if there are the arguments __init__(self,argument), then the argument is mandatory to pass.
# ## Else if there is argument=None, that means we can either pass or not required to pass the argument.

# %%
import torch 
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np
import math 

class WineDataset(Dataset):
    def __init__(self,transform):
        xy=np.loadtxt('wine.csv',delimiter=',',dtype=np.float32,skiprows=1)
        self.x=xy[:,1:]
        self.y=xy[:,[0]]
        self.n_samples=xy.shape[0]
        self.transform=transform
         
        
    def __getitem__(self,index):
            sample=self.x[index],self.y[index]
            
            if self.transform:
                sample=self.transform(sample)
                
            return sample
        
            
    def __len__(self):
        return self.n_samples

    
class ToTensor:
    def __call__(self,sample):
        inputs,targets=sample
        return torch.from_numpy(inputs),torch.from_numpy(targets)
    
class MulTransform:
    def __init__(self,factor):
        self.factor=factor
        
    def __call__(self,sample):
        inputs,target = sample
        inputs*=self.factor
        return inputs,target
    
    
    
    

dataset=WineDataset(transform=None) # no Transformation applied.
firstdata=dataset[0]
features,labels=firstdata
print('features',features)
print('labels',labels)


composed=torchvision.transforms.Compose([ToTensor(),MulTransform(4)]) #2*Transformation applied via Multransform and ToTensor combined 
#with compose transform.
dataset=WineDataset(transform=composed)
firstdata=dataset[0]
features,labels=firstdata
print('features',features)
print('labels',labels)
print(type(features),type(labels))
# Out:
# features [1.423e+01 1.710e+00 2.430e+00 1.560e+01 1.270e+02 2.800e+00 3.060e+00
#  2.800e-01 2.290e+00 5.640e+00 1.040e+00 3.920e+00 1.065e+03]
# labels [1.]
# features tensor([5.6920e+01, 6.8400e+00, 9.7200e+00, 6.2400e+01, 5.0800e+02, 1.1200e+01,
#         1.2240e+01, 1.1200e+00, 9.1600e+00, 2.2560e+01, 4.1600e+00, 1.5680e+01,
#         4.2600e+03])
# labels tensor([1.])
# <class 'torch.Tensor'> <class 'torch.Tensor'>

# %% [markdown]
# # Softmax and Cross Entropy using numpy

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import torch 
import torch.nn as nn
import numpy as np

def softmax(x):
    return np.exp(x)/(np.sum(np.exp(x),axis=0))

x=np.array([2.0,1.0,0.1])
                      
output=softmax(x)

print('softmax numpy',output)


def cross_entropy(actual,predicted):
    loss=-np.sum(actual*np.log(predicted))
    return loss
    


Y=np.array([1,0,0]) # should be one hot encoded.

Y_pred_good=np.array([0.7,0.2,0.1])
Y_pred_bad=np.array([0.1,0.3,0.6])

l1=cross_entropy(Y,Y_pred_good)
l2=cross_entropy(Y,Y_pred_bad)

print('l1 Cross Entropy is the loss function',l1)
print('l2 Cross Entropy',l2)
# Out:
# softmax numpy [0.65900114 0.24243297 0.09856589]
# l1 Cross Entropy is the loss function 0.35667494393873245
# l2 Cross Entropy 2.3025850929940455

# %% [markdown]
# # Softmax and Cross Entropy using Pytorch

# %%
x=torch.tensor([2.0,1.0,0.1])
outputs=torch.softmax(x,dim=0)
print('Softmax Pytorch',outputs)

loss=nn.CrossEntropyLoss()

Y=torch.tensor([2,0,1])  # for class 0,1,2, we have output value 0.
#But for one single output 0, we have 3 different probabilites in the y_pred_good or y_pred_bad.
#n_samples x n_classes=1 x 3
Y_pred_good1=torch.tensor([[0.1,1.0,2.1],[2.0,1.0,0.1],[0.1,3.0,0.1]])
Y_pred_bad1=torch.tensor([[2.1,1.0,0.1],[0.1,1.0,2.1],[0.1,3.0,0.1]])

l1=loss(Y_pred_good1,Y)
l2=loss(Y_pred_bad1,Y)

print('L1 loss ',l1.item())
print('L2 loss',l2.item())

    
_,predictions1=torch.max(Y_pred_good1,1) #1 here is 1-d
_,predictions2=torch.max(Y_pred_bad1,1) #1 here is 1-d

print(predictions1)
print(predictions2)
# Out:
# Softmax Pytorch tensor([0.6590, 0.2424, 0.0986])
# L1 loss  0.3018244206905365
# L2 loss 1.6241613626480103
# tensor([2, 0, 1])
# tensor([0, 2, 1])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## When weights dont get updated much, try to use this leaky RELU function.

# %% [markdown]
# # Feed Forward Neural Network!(Finally)

# %%
# MNIST
import torch 
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# device config
device= torch.device('cuda' if torch.cuda.is_available() else 'cpu')


# hyper parameters
input_size=784    #  28*28
hidden_size=500
hidden_size1=200
num_classes=10
num_epochs=2
batch_size=100
learning_rate=0.001


#MNIST

train_dataset=torchvision.datasets.MNIST(root='./data',train=True,transform=transforms.ToTensor(),download=True)
test_dataset=torchvision.datasets.MNIST(root='./data',train=False,transform=transforms.ToTensor())


train_loader=torch.utils.data.DataLoader(dataset=train_dataset,batch_size=batch_size,shuffle=True)
test_loader=torch.utils.data.DataLoader(dataset=test_dataset,batch_size=batch_size,shuffle=False)


examples=iter(train_loader)
samples,labels=examples.next()
print(samples.shape)
print(labels.shape)

for i in range(6):
    plt.subplot(2,3,i+1)
    plt.imshow(samples[i][0],cmap='gray')
    #plt.show()
    
class NeuralNet(nn.Module):
    def __init__(self,input_size,hidden_size,hidden_size1,num_classes):
        super(NeuralNet, self).__init__()
        self.input_size = input_size
        self.l1=nn.Linear(input_size,hidden_size)
        self.relu=nn.ReLU()
        self.l2=nn.Linear(hidden_size,hidden_size1)
        self.l3=nn.Linear(hidden_size1,num_classes)
        
        
        
    def forward(self,x):
        out=self.l1(x) #x - images of reshaped size 28*28 = 784, which should resemble input_size.
        out=self.relu(out)
        out=self.l2(out)
        out=self.l3(out)
        return out
        
model = NeuralNet(input_size,hidden_size,hidden_size1,num_classes).to(device)

#loss and optimizer
criterion=nn.CrossEntropyLoss()
optimizer=torch.optim.Adam(model.parameters(),lr=learning_rate)


#trainining loop
n_total_steps=len(train_loader)

for epoch in range(num_epochs):
    for i,(images,labels) in enumerate(train_loader):
        #100,1,28,28
        #100,784
        images=images.reshape(-1,28*28).to(device) # Image is converted to a single vector of size
        labels=labels.to(device)
        
        #forward
        outputs=model.forward(images)
        loss=criterion(outputs,labels)
        
        
        #backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if(i+1)%100==0:
            print(f'epoch {epoch+1}/{num_epochs}, step{i+1}/{n_total_steps}, loss={loss.item():.4f}')
            
#test (we dont want to compute gradients for testing)
with torch.no_grad():
    n_correct=0#no of correct predictions.
    n_samples=0
    for images,labels in test_loader:
        images=images.reshape(-1,28*28).to(device)
        labels=labels.to(device)
        outputs=model.forward(images)
        
        #values, index
        _,predictions=torch.max(outputs.data,1)
        n_samples+=labels.size(0)
        n_correct+=(predictions==labels).sum().item()
    acc=100.0*n_correct/n_samples
    print(f'accuracy: {acc}')
# Out:
# torch.Size([100, 1, 28, 28])
# torch.Size([100])
# epoch 1/2, step100/600, loss=0.2699
# epoch 1/2, step200/600, loss=0.2857
# epoch 1/2, step300/600, loss=0.1844
# epoch 1/2, step400/600, loss=0.1736
# epoch 1/2, step500/600, loss=0.1110
# epoch 1/2, step600/600, loss=0.1721
# epoch 2/2, step100/600, loss=0.0937
# epoch 2/2, step200/600, loss=0.1385
# epoch 2/2, step300/600, loss=0.0278
# epoch 2/2, step400/600, loss=0.0746
# epoch 2/2, step500/600, loss=0.0828
# epoch 2/2, step600/600, loss=0.0494
# accuracy: 97.76
